# %%
from pathlib import Path
import re
import matplotlib.pyplot as plt
import numpy as np

# %%
result_dir = Path("results")
metrics = [
  "board.processor.cores.core.ipc",
  "board.processor.cores.core.cpi",
  ]

# %%
widths = []
robs = []

results = []

data_str = ""

for dir in result_dir.glob("*"):
  name = dir.name
  stat_file = dir / "stats.txt"

  width = int(name.split("_")[1].replace("width",""))
  if(width not in widths):
    widths.append(width)

  rob = int(name.split("_")[2].replace("rob",""))
  if(rob not in robs):
    robs.append(rob)
  
  index = [widths.index(width), robs.index(rob)]
  print(index)
  
  with open(stat_file) as result_file:
   content = result_file.read()
   for metric in metrics:
    matcher = f"{metric}[ ]*([0-9].[0-9]*)" 

    metric_search = re.search(matcher, content, re.IGNORECASE)
    if metric_search:
        result = float(metric_search.group(1))
    
    results.append([index, metric, result])

    out_str = (f"Issue Width : {width} | Reorder Buffer (ROB) Size:{rob} : | Metric: {metric.split(".")[-1]}:  {result}\n")
    data_str += out_str
    print(out_str)
# Out:
# [0, 0]
# Issue Width : 1 | Reorder Buffer (ROB) Size:2 : | Metric: ipc:  0.180436
#
# Issue Width : 1 | Reorder Buffer (ROB) Size:2 : | Metric: cpi:  5.542123
#
# [0, 1]
# Issue Width : 1 | Reorder Buffer (ROB) Size:4 : | Metric: ipc:  0.275011
#
# Issue Width : 1 | Reorder Buffer (ROB) Size:4 : | Metric: cpi:  3.636221
#
# [0, 2]
# Issue Width : 1 | Reorder Buffer (ROB) Size:8 : | Metric: ipc:  0.504307
#
# Issue Width : 1 | Reorder Buffer (ROB) Size:8 : | Metric: cpi:  1.982919
#
# [0, 3]
# Issue Width : 1 | Reorder Buffer (ROB) Size:16 : | Metric: ipc:  0.543025
#
# Issue Width : 1 | Reorder Buffer (ROB) Size:16 : | Metric: cpi:  1.841535
#
# [0, 4]
# Issue Width : 1 | Reorder Buffer (ROB) Size:32 : | Metric: ipc:  0.543047
#
# Issue Width : 1 | Reorder Buffer (ROB) Size:32 : | Metric: cpi:  1.84146
#
# [1, 0]
# Issue Width : 2 | Reorder Buffer (ROB) Size:2 : | Metric: ipc:  0.180461
#
# Issue Width : 2 | Reorder Buffer (ROB) Size:2 : | Metric: cpi:  5.541362
#
# [1, 1]
# Issue Width : 2 | Reorder Buffer (ROB) Size:4 : | Metric: ipc:  0.335632
#
# Issue Width : 2 | Reorder Buffer (ROB) Size:4 : | Metric: cpi:  2.979452
#
# [1, 2]
# Issue Width : 2 | Reorder Buffer (ROB) Size:8 : | Metric: ipc:  0.539686
#
# Issue Width : 2 | Reorder Buffer (ROB) Size:8 : | Metric: cpi:  1.852928
#
# [1, 3]
# Issue Width : 2 | Reorder Buffer (ROB) Size:16 : | Metric: ipc:  0.910005
#
# Issue Width : 2 | Reorder Buffer (ROB) Size:16 : | Metric: cpi:  1.098894
#
# [1, 4]
# Issue Width : 2 | Reorder Buffer (ROB) Size:32 : | Metric: ipc:  0.96843
#
# Issue Width : 2 | Reorder Buffer (ROB) Size:32 : | Metric: cpi:  1.0326
#
# [2, 0]
# Issue Width : 4 | Reorder Buffer (ROB) Size:2 : | Metric: ipc:  0.180461
#
# Issue Width : 4 | Reorder Buffer (ROB) Size:2 : | Metric: cpi:  5.54135
#
# [2, 1]
# Issue Width : 4 | Reorder Buffer (ROB) Size:4 : | Metric: ipc:  0.341416
#
# Issue Width : 4 | Reorder Buffer (ROB) Size:4 : | Metric: cpi:  2.928978
#
# [2, 2]
# Issue Width : 4 | Reorder Buffer (ROB) Size:8 : | Metric: ipc:  0.614891
#
# Issue Width : 4 | Reorder Buffer (ROB) Size:8 : | Metric: cpi:  1.626304
#
# [2, 3]
# Issue Width : 4 | Reorder Buffer (ROB) Size:16 : | Metric: ipc:  0.985097
#
# Issue Width : 4 | Reorder Buffer (ROB) Size:16 : | Metric: cpi:  1.015129
#
# [2, 4]
# Issue Width : 4 | Reorder Buffer (ROB) Size:32 : | Metric: ipc:  1.254026
#
# Issue Width : 4 | Reorder Buffer (ROB) Size:32 : | Metric: cpi:  0.797432
#
# [3, 0]
# Issue Width : 8 | Reorder Buffer (ROB) Size:2 : | Metric: ipc:  0.180462
#
# Issue Width : 8 | Reorder Buffer (ROB) Size:2 : | Metric: cpi:  5.541322
#
# [3, 1]
# Issue Width : 8 | Reorder Buffer (ROB) Size:4 : | Metric: ipc:  0.34159
#
# Issue Width : 8 | Reorder Buffer (ROB) Size:4 : | Metric: cpi:  2.927486
#
# [3, 2]
# Issue Width : 8 | Reorder Buffer (ROB) Size:8 : | Metric: ipc:  0.62592
#
# Issue Width : 8 | Reorder Buffer (ROB) Size:8 : | Metric: cpi:  1.597649
#
# [3, 3]
# Issue Width : 8 | Reorder Buffer (ROB) Size:16 : | Metric: ipc:  1.04728
#
# Issue Width : 8 | Reorder Buffer (ROB) Size:16 : | Metric: cpi:  0.954855
#
# [3, 4]
# Issue Width : 8 | Reorder Buffer (ROB) Size:32 : | Metric: ipc:  1.362614
#
# Issue Width : 8 | Reorder Buffer (ROB) Size:32 : | Metric: cpi:  0.733883

# %%
def get_heatmap_data_from_res(res):
  for metric in metrics:
    y_names = widths
    x_names = robs
    data = np.zeros([len(x_names), len(y_names)])
    for r in res:
      if(r[1] == metric):
        data[r[0][1], r[0][0]] = r[2]
    yield (x_names, y_names, data, metric)

# %%
heatm_folder = Path("heatmaps")

# %%
def create_heatmap(x_names, y_names, data,metric):
  fig, ax = plt.subplots()
  im = ax.imshow(data)

  # Show all ticks and label them with the respective list entries
  ax.set_xticks(range(len(y_names)), labels=y_names,
                rotation=45, ha="right", rotation_mode="anchor")
  ax.set_yticks(range(len(x_names)), labels=x_names)

  # Loop over data dimensions and create text annotations.
  for i in range(len(x_names)):
      for j in range(len(y_names)):
          text = ax.text(j, i, data[i, j],
                        ha="center", va="center", color="w")

  ax.set_title(metric)
  ax.set_ylabel("ROB Size")
  ax.set_xlabel("Issue width")
  fig.tight_layout()
  fig.savefig(heatm_folder / f"{metric}.png")
  plt.show()
  return fig

# %%
for out in get_heatmap_data_from_res(results):
  create_heatmap(*out)

# %%
from ollama import Client
client = Client(
  host='http://localhost:11434',
)

for model in client.list()["models"]:
  print(model["model"])
# Out:
# deepscaler:1.5b
# gemma3:4b
# qwen2.5-coder:1.5b

# %%
navodilo = open("navodilo.txt").read()
prompt = f"I'll give you the exercise and the data, generate a short report. Answer strictly just the questions from the task provided!: \n {navodilo} \n Here is the data: \n {data_str}"

# %%
out = client.generate("deepscaler:1.5b", prompt=prompt)

# %%
open("report.md", "w").write(out["response"].split("</think>")[-1])
# Out:
# 2591

# %%
prompt
# Out:
# "I'll give you the exercise and the data, generate a short report. Answer strictly just the questions from the task provided!: \n In the first task, you will evaluate the performance of the O3 processor model that we developed during the lab exercises. To carry out this assessment, you will use the Whetstone benchmark, which can be found in the workload/Whetstone/ folder.\n\nWhetstone benchmark\nThe Whetstone benchmark is an one of the method used to evaluate CPU performance, particularly for scientific applications. It consists of several modules that represent a range of operations commonly performed in scientific programs. The benchmark utilizes a variety of C functions, including sin, cos, sqrt, exp, and log, along with integer and floating-point mathematical operations, array accesses, conditional branches, and procedure calls.\n\nObjectives\n\nEvaluate the performance of the out-of-order (OoO) processor by running the Whetstone benchmark in GEM5. Modify the following parameters of the out-of-order (O3) processor:\n\nIssue Width: 1, 2, 4, 8\n\nReorder Buffer (ROB) Size: 2, 4, 8, 16, 32\n\nRun the Whetstone benchmark for each combination of these parameters and record the results. When analyzing performance, consider the following metrics:\n\n\nIPC (Instructions Per Cycle)\n\nCPI (Cycles Per Instruction) \n Here is the data: \n Issue Width : 1 | Reorder Buffer (ROB) Size:2 : | Metric: ipc:  0.180436\nIssue Width : 1 | Reorder Buffer (ROB) Size:2 : | Metric: cpi:  5.542123\nIssue Width : 1 | Reorder Buffer (ROB) Size:4 : | Metric: ipc:  0.275011\nIssue Width : 1 | Reorder Buffer (ROB) Size:4 : | Metric: cpi:  3.636221\nIssue Width : 1 | Reorder Buffer (ROB) Size:8 : | Metric: ipc:  0.504307\nIssue Width : 1 | Reorder Buffer (ROB) Size:8 : | Metric: cpi:  1.982919\nIssue Width : 1 | Reorder Buffer (ROB) Size:16 : | Metric: ipc:  0.543025\nIssue Width : 1 | Reorder Buffer (ROB) Size:16 : | Metric: cpi:  1.841535\nIssue Width : 1 | Reorder Buffer (ROB) Size:32 : | Metric: ipc: