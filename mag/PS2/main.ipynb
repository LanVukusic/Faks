# %%
import numpy as np
from matplotlib.image import imread
import matplotlib.pyplot as plt

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Broadway_tower_edit.jpg/274px-Broadway_tower_edit.jpg -O slika.jpg
# Out:
# 7[Files: 0  Bytes: 0  [0 B/s] Re]87[https://upload.wikimedia.org/w]87Saving 'slika.jpg'
# 87slika.jpg            100% [=============================>]   16.30K    --.-KB/s87HTTP response 200  [https://upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Broadway_tower_edit.jpg/274px-Broadway_tower_edit.jpg]
# 87slika.jpg            100% [=============================>]   16.30K    --.-KB/s87[Files: 1  Bytes: 16.30K [80.33]8

# %%
im = imread("slika.jpg")
plt.imshow(im)

# %%
sobel_x = np.array([
  [-1,0,1],
  [-2,0,2],
  [-1,0,1],
])

sobel_y = sobel_x.T
plt.imshow(sobel_y)

# %%
im.shape
# Out:
# (186, 274, 3)

# %%
conv = np.convolve(im[:,:,0], sobel_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 conv = np.convolve(im[:,:,0], sobel_y)
#
# File ~/Faks/mag/PS2/.venv/lib64/python3.13/site-packages/numpy/_core/numeric.py:869, in convolve(a, v, mode)
#     867 if len(v) == 0:
#     868     raise ValueError('v cannot be empty')
# --> 869 return multiarray.correlate(a, v[::-1], mode)
#
# ValueError: object too deep for desired array
