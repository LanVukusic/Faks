# %%
import networkx as nx
import utils

# %%
G = nx.Graph(utils.read_pajek("traffic", "."))
utils.info(G)

print(G.nodes(data=True))
# Out:
#        Graph | 'traffic'
#        Nodes | 806 (iso=0)
#        Edges | 6,915 (loop=0)
#       Degree | 17.16 (max=191)
#          LCC | 100.0% (n=1)
#   Clustering | 0.5416
#
# ...
